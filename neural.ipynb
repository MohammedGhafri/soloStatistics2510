# %% [markdown]
# # Neural Networks

# %% [markdown]
# ### We can create a dataset of the size and complexity needed

# %%
from sklearn.datasets import make_classification,make_circles,make_moons
X, y = make_classification(n_samples=25,n_features=2, n_redundant=0, n_informative=2, random_state=3)
# print(X)
# print(y)

# %% [markdown]
# ### Scikit-learn has a couple other functions besides make_classification for making classification datasets with different properties. Look at make_circles and make_moons if you want to play around with more artificial datasets.

# %%
from matplotlib import pyplot as plt
plt.scatter(X[y==0][:, 0], X[y==0][:, 1], s=100, edgecolors='k')
plt.scatter(X[y==1][:, 0], X[y==1][:, 1], s=100, edgecolors='k', marker='^')
plt.show()

# %%
X, y = make_classification(n_features=3, n_redundant=1, n_informative=2)

# %% [markdown]
# ### make_circles

# %%
X,y=make_circles(n_samples=100,  shuffle=True, noise=None, random_state=None, factor=0.8)

# %%
plt.scatter(X[y==0][:, 0], X[y==0][:, 1], s=100, edgecolors='k')
plt.scatter(X[y==1][:, 0], X[y==1][:, 1], s=100, edgecolors='k', marker='^')
plt.show()

# %% [markdown]
# ### make_moons

# %%
X,y=make_moons(n_samples=100,  shuffle=True, noise=None, random_state=None)

# %%
plt.scatter(X[y==0][:, 0], X[y==0][:, 1], s=100, edgecolors='k')
plt.scatter(X[y==1][:, 0], X[y==1][:, 1], s=100, edgecolors='k', marker='^')
plt.show()

# %%
from sklearn.model_selection import train_test_split
from sklearn.neural_network import MLPClassifier
from sklearn.datasets import make_classification

# %%
X,y = make_classification(n_features=2, n_redundant=0,n_informative=2,random_state=3)
X_train,X_test,y_train,y_test=train_test_split(X,y,random_state=3)
mlp=MLPClassifier()
mlp.fit(X_train,y_train)

# X, y = make_classification(n_features=2, n_redundant=0, n_informative=2, random_state=3)
# X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=3)
# mlp = MLPClassifier()
# mlp.fit(X_train, y_train)
# Out:
# /home/ghafri/soloStatistics2510/.venv/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# MLPClassifier()

# %% [markdown]
# ### You will notice that we get a ConvergenceWarning. This means that the neural network needs more iterations to converge on the optimal coefficients. The default number of iterations is 200. Let’s up this value to 1000.

# %%
mlp=MLPClassifier(max_iter=1000)
mlp.fit(X_train,y_train)
# Out:
# MLPClassifier(max_iter=1000)

# %%
print("accuracy:", mlp.score(X_test, y_test))
# Out:
# accuracy: 0.64

# %% [markdown]
# ### solver: 'lbfgs', 'sgd', 'adam'

# %%
mlp = MLPClassifier(max_iter=1000, hidden_layer_sizes=(100, 50), alpha=0.0001, solver='adam', random_state=3)
mlp.fit(X_train, y_train)
print("accuracy:", mlp.score(X_test, y_test))
# Out:
# accuracy: 0.76

# %% [markdown]
# [Link to docs](https://scikit-learn.org/stable/modules/generated/sklearn.neural_network.MLPClassifier.html)

# %% [markdown]
# ## MNIST

# %%
from sklearn.datasets import load_digits
X, y = load_digits(n_class=2, return_X_y=True)
print(X.shape, y.shape)
print(X[0])
print(y[0])
print(X[0].reshape(8, 8))
# Out:
# (360, 64) (360,)
# [ 0.  0.  5. 13.  9.  1.  0.  0.  0.  0. 13. 15. 10. 15.  5.  0.  0.  3.
#  15.  2.  0. 11.  8.  0.  0.  4. 12.  0.  0.  8.  8.  0.  0.  5.  8.  0.
#   0.  9.  8.  0.  0.  4. 11.  0.  1. 12.  7.  0.  0.  2. 14.  5. 10. 12.
#   0.  0.  0.  0.  6. 13. 10.  0.  0.  0.]
# 0
# [[ 0.  0.  5. 13.  9.  1.  0.  0.]
#  [ 0.  0. 13. 15. 10. 15.  5.  0.]
#  [ 0.  3. 15.  2.  0. 11.  8.  0.]
#  [ 0.  4. 12.  0.  0.  8.  8.  0.]
#  [ 0.  5.  8.  0.  0.  9.  8.  0.]
#  [ 0.  4. 11.  0.  1. 12.  7.  0.]
#  [ 0.  2. 14.  5. 10. 12.  0.  0.]
#  [ 0.  0.  6. 13. 10.  0.  0.  0.]]

# %%
import matplotlib.pyplot as plt
# from sklearn.datasets import load_digits

# X, y = load_digits(n_class=2, return_X_y=True)
## The cmap parameter is used to indicate that the image should be in a grayscale rather than colored
plt.matshow(X[0].reshape(8, 8), cmap=plt.cm.gray)
plt.xticks(())  # remove x tick marks
plt.yticks(())  # remove y tick marks
plt.show()

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=2)
mlp = MLPClassifier()
mlp.fit(X_train, y_train)
# Out:
# MLPClassifier()

# %%
# print(X.shape)
